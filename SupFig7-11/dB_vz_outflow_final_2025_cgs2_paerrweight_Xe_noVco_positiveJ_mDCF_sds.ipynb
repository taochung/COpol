# %%
#Dec/22/2024 chingtaochung@gmail.com
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import matplotlib as mpl
font = {'size'   : 6}
mpl.rc('font', **font)
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = ['Arial']
minorLocator = MultipleLocator(10)

i20 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/n20.txt") #in cm-3
dB20 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/dB20.txt")/1e3 #from mG/cm to G/cm  
dBerr20 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/dBerr20.txt")/1e3  
i21 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/n21.txt")
dB21 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/dB21.txt")/1e3
dBerr21 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/dBerr21.txt")/1e3   
i22 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/n22.txt")
dB22 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/dB22.txt")/1e3
dBerr22 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/dBerr22.txt")/1e3  
i23 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/n23.txt")
dB23 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/dB23.txt")/1e3
dBerr23 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2025/sn3_3_imbin_x5y3_Gauss_uncertainty_251210_positiveJ_mDCF/output/dBerr23.txt")/1e3 

i20_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/n20.txt") #in cm-3
dB20_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dB20.txt")/1e3 #from mG/cm to G/cm  
dBerr20_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dBerr20.txt")/1e3  
i21_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/n21.txt")
dB21_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dB21.txt")/1e3
dBerr21_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dBerr21.txt")/1e3   
i22_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/n22.txt")
dB22_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dB22.txt")/1e3
dBerr22_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dBerr22.txt")/1e3  
i23_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/n23.txt")
dB23_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dB23.txt")/1e3
dBerr23_2 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dBerr23.txt")/1e3 

fig=plt.figure(figsize=(3.45,3.45*4.8/6.4))
plt.subplots_adjust(left=0.15, right=0.9, top=0.9, bottom=0.15)

left = 0.125  # the left side of the subplots of the figure
right = 0.9   # the right side of the subplots of the figure
bottom = 0.1  # the bottom of the subplots of the figure
top = 0.9     # the top of the subplots of the figure
wspace = 0.2  # the amount of width reserved for space between subplots,
              # expressed as a fraction of the average axis width
hspace = 0.2  # the amount of height reserved for space between subplots,
              # expressed as a fraction of the average axis height

marker_size=6
plt_alpha = 1

e2esu = 4.803e-10 #e = 4.8e-10 esu
v0 = 1. #-1 representing the current direction is opposite to outflow direction
c = 2.998e10 #light speed in cm s-1

v20=4*np.pi*v0*e2esu/c*1e21 
v21=4*np.pi*v0*e2esu/c*1e21 
v22=4*np.pi*v0*e2esu/c*1e21 
v23=4*np.pi*v0*e2esu/c*1e21 

dB20 = dB20*1e18
dB21 = dB21*1e18 
dB22 = dB22*1e18 
dB23 = dB23*1e18 
dBerr20 = dBerr20*1e18 
dBerr21 = dBerr21*1e18 
dBerr22 = dBerr22*1e18 
dBerr23 = dBerr23*1e18
x23 = np.sqrt(2*i23)*1e-5
x22 = np.sqrt(2*i22)*1e-5
x21 = np.sqrt(2*i21)*1e-5
x20 = np.sqrt(2*i20)*1e-5

dB20_2 = dB20_2*1e18
dB21_2 = dB21_2*1e18 
dB22_2 = dB22_2*1e18 
dB23_2 = dB23_2*1e18 
dBerr20_2 = dBerr20_2*1e18 
dBerr21_2 = dBerr21_2*1e18 
dBerr22_2 = dBerr22_2*1e18 
dBerr23_2 = dBerr23_2*1e18
x23_2 = np.sqrt(2*i23_2)*1e-5
x22_2 = np.sqrt(2*i22_2)*1e-5
x21_2 = np.sqrt(2*i21_2)*1e-5
x20_2 = np.sqrt(2*i20_2)*1e-5

colors = ['#56b4e9','#0072b2','#d55e00','#e69f00']
          
plt.errorbar(x23*v23, dB23, yerr=dBerr23, fmt='^', color=colors[0], markerfacecolor='none', alpha=plt_alpha, markersize=marker_size,label=r'V$_{CO}$ +3.090 km s$^{-1}$')
plt.errorbar(x22*v22, dB22, yerr=dBerr22, fmt='o', color=colors[1], markerfacecolor='none', alpha=plt_alpha, markersize=marker_size,label=r'V$_{CO}$ +6.265 km s$^{-1}$')
plt.errorbar(x21*v21, dB21, yerr=dBerr21, fmt='s', color=colors[2], markerfacecolor='none', alpha=plt_alpha, markersize=marker_size,label=r'V$_{CO}$ +9.440 km s$^{-1}$')
plt.errorbar(x20*v20, dB20, yerr=dBerr20, fmt='D', color=colors[3], markerfacecolor='none', alpha=plt_alpha, markersize=marker_size,label=r'V$_{CO}$ +12.615 km s$^{-1}$')
plt.legend(loc=4,fontsize="6",ncol=1)

plt.errorbar(x23_2*v23, dB23_2, yerr=dBerr23_2, fmt='^', color=colors[0], markerfacecolor='none', alpha=plt_alpha*0.2, markersize=marker_size,label=r'V$_{CO}$ +3.090 km s$^{-1}$')
plt.errorbar(x22_2*v22, dB22_2, yerr=dBerr22_2, fmt='o', color=colors[1], markerfacecolor='none', alpha=plt_alpha*0.2, markersize=marker_size,label=r'V$_{CO}$ +6.265 km s$^{-1}$')
plt.errorbar(x21_2*v21, dB21_2, yerr=dBerr21_2, fmt='s', color=colors[2], markerfacecolor='none', alpha=plt_alpha*0.2, markersize=marker_size,label=r'V$_{CO}$ +9.440 km s$^{-1}$')
plt.errorbar(x20_2*v20, dB20_2, yerr=dBerr20_2, fmt='D', color=colors[3], markerfacecolor='none', alpha=plt_alpha*0.2, markersize=marker_size,label=r'V$_{CO}$ +12.615 km s$^{-1}$')
plt.tick_params(axis='y', right=True, labelright=False)
plt.tick_params(axis='x', top=True, labeltop=False)

y = np.concatenate((dB20,dB21,dB22,dB23))
yerr = np.concatenate((dBerr20,dBerr21,dBerr22,dBerr23))
x = np.concatenate((x20*v20,x21*v21,x22*v22,x23*v23))

plt.xlabel(r'$\frac{4\pi}{c} \varrho_c$ ($10^{-21}$ cm$^{-5/2}$ g$^{1/2}$)')
plt.ylabel(r'$\frac{\partial B_y}{\partial x}-\frac{\partial B_x}{\partial y}$ ($10^{-18}$ cm$^{-3/2}$ g$^{1/2}$ s$^{-1}$)')
plt.xlim(1,2.2)

######
from scipy.optimize import curve_fit

def func(x, a, b):
    return a * x + b

popt, pcov = curve_fit(func, x, y, sigma=yerr, absolute_sigma=True, method='dogbox')
print(popt)
print(np.sqrt(np.diag(pcov)))
#####

import uncertainties.unumpy as unp
import uncertainties as unc

a2,b2 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a2: ' + str(a2))
print('b2: ' + str(b2))

xp = np.linspace(1, 2.2, 100)
py2 = a2*xp+b2
nom1 = unp.nominal_values(py2)
std1 = unp.std_devs(py2)

plt.fill_between(xp, nom1 - 1.96 * std1, nom1 + 1.96 * std1, facecolor='grey', interpolate=True,
                linewidth=0.0,alpha=0.2,label='95% Confidence Region',zorder=0)
plt.plot(xp, nom1, 'k-')

py1 = 0.59108255*xp-0.84875432
plt.plot(xp, py1, 'k--')

plt.savefig('dB_vz_outflow_final_2025_cgs2_chan_paerrweight_Xe_noVco_positiveJ_mDCF_sds.pdf')

#from python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/dB_vz_outflow_final_2024_cgs2_241022_paerrweight_Xe_noVco_positiveJ.ipynb
#[ 0.59108255 -0.84875432]
#[0.18100348 0.29423851]
#Uncertainty
#a2: 0.59+/-0.18
#b2: -0.85+/-0.29

#[ 0.58084251 -0.76016262]
#[0.15213829 0.25363285]
#Uncertainty
#a2: 0.58+/-0.15
#b2: -0.76+/-0.25
# Out:
# <style>.container { width:100% !important; }</style>
# [ 0.60484591 -0.79705548]
# [0.15369651 0.25574752]
# Uncertainty
# a2: 0.60+/-0.15
# b2: -0.80+/-0.26

# %%
print(*(x23*v23), sep='\n')
print('#####')
print(*(dB23), sep='\n')
print('#####')
print(*(dBerr23), sep='\n')
# Out:
# 1.1471940530516282
# 1.24999052661412
# 1.293427669320903
# #####
# -0.00038025097037999115
# -0.22487857092063293
# -0.8685806257185728
# #####
# 0.25887872574765425
# 0.5816152090414558
# 0.4037590302388725

# %%
#plt.plot(xp, nom1, 'k-')
print(*(xp), sep='\n')
print('#####')
print(*(nom1), sep='\n')
# Out:
# 1.0
# 1.0121212121212122
# 1.0242424242424242
# 1.0363636363636364
# 1.0484848484848486
# 1.0606060606060606
# 1.0727272727272728
# 1.084848484848485
# 1.096969696969697
# 1.1090909090909091
# 1.1212121212121213
# 1.1333333333333333
# 1.1454545454545455
# 1.1575757575757577
# 1.1696969696969697
# 1.1818181818181819
# 1.1939393939393939
# 1.206060606060606
# 1.2181818181818183
# 1.2303030303030305
# 1.2424242424242424
# 1.2545454545454546
# 1.2666666666666666
# 1.2787878787878788
# 1.290909090909091
# 1.3030303030303032
# 1.3151515151515152
# 1.3272727272727274
# 1.3393939393939394
# 1.3515151515151516
# 1.3636363636363638
# 1.3757575757575757
# 1.387878787878788
# 1.4000000000000001
# 1.412121212121212
# 1.4242424242424243
# 1.4363636363636365
# 1.4484848484848485
# 1.4606060606060607
# 1.4727272727272727
# 1.4848484848484849
# 1.496969696969697
# 1.5090909090909093
# 1.5212121212121212
# 1.5333333333333334
# 1.5454545454545454
# 1.5575757575757576
# 1.5696969696969698
# ...
