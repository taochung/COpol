# %%
#Dec/22/2024 chingtaochung@gmail.com
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import matplotlib as mpl
font = {'size'   : 10}
mpl.rc('font', **font)
minorLocator = MultipleLocator(10)

i20 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/n20.txt") #in cm-3
dB20 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dB20.txt")/1e3 #from mG/cm to G/cm  
dBerr20 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dBerr20.txt")/1e3  
i21 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/n21.txt")
dB21 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dB21.txt")/1e3
dBerr21 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dBerr21.txt")/1e3   
i22 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/n22.txt")
dB22 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dB22.txt")/1e3
dBerr22 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dBerr22.txt")/1e3  
i23 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/n23.txt")
dB23 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dB23.txt")/1e3
dBerr23 = np.loadtxt("/Users/tching/Desktop/proposals/ALMA/Cycle4/COpolarization/python_2024/sn3_3_imbin_x5y3_Gauss_uncertainty_241022_positiveJ/output/dBerr23.txt")/1e3 

plt.figure()
plt.subplots_adjust(left=0.15, right=0.9, top=0.9, bottom=0.15)

left = 0.125  # the left side of the subplots of the figure
right = 0.9   # the right side of the subplots of the figure
bottom = 0.1  # the bottom of the subplots of the figure
top = 0.9     # the top of the subplots of the figure
wspace = 0.2  # the amount of width reserved for space between subplots,
              # expressed as a fraction of the average axis width
hspace = 0.2  # the amount of height reserved for space between subplots,
              # expressed as a fraction of the average axis height

marker_size=6
plt_alpha = 1

e2esu = 4.803e-10 #e = 4.803e-10 esu
v0 = 1e5 #km/s to cm/s, -1 representing the current direction is opposite to outflow direction
vsys = 6.86 #6.86 in km/s
c = 2.998e10 #light speed in cm s-1

v20=4*np.pi*(19.475-vsys)*v0*e2esu/c*1e15 
v21=4*np.pi*(16.300-vsys)*v0*e2esu/c*1e15
v22=4*np.pi*(13.125-vsys)*v0*e2esu/c*1e15
v23=4*np.pi*(9.950-vsys)*v0*e2esu/c*1e15 

dB20 = dB20*1e18
dB21 = dB21*1e18 
dB22 = dB22*1e18 
dB23 = dB23*1e18 
dBerr20 = dBerr20*1e18 
dBerr21 = dBerr21*1e18 
dBerr22 = dBerr22*1e18 
dBerr23 = dBerr23*1e18 

x23 = np.sqrt(2*i23)*1e-5
x22 = np.sqrt(2*i22)*1e-5
x21 = np.sqrt(2*i21)*1e-5
x20 = np.sqrt(2*i20)*1e-5

plt.errorbar(x23*v23, dB23, yerr=dBerr23, fmt='^', color='#87CEEB', alpha=plt_alpha, markersize=marker_size,label=r'V$_{CO}$ +3.090 km s$^{-1}$')
plt.errorbar(x22*v22, dB22, yerr=dBerr22, fmt='o', color='#DC143C', alpha=plt_alpha, markersize=marker_size,label=r'V$_{CO}$ +6.265 km s$^{-1}$')
plt.errorbar(x21*v21, dB21, yerr=dBerr21, fmt='s', color='#FFA500', alpha=plt_alpha, markersize=marker_size,label=r'V$_{CO}$ +9.440 km s$^{-1}$')
plt.errorbar(x20*v20, dB20, yerr=dBerr20, fmt='D', color='#228B22', alpha=plt_alpha, markersize=marker_size,label=r'V$_{CO}$ +12.615 km s$^{-1}$')
plt.legend(loc=4,fontsize="8",ncol=1)

plt.tick_params(axis='y', right=True, labelright=False)
plt.tick_params(axis='x', top=True, labeltop=False)

y = np.concatenate((dB20,dB21,dB22,dB23))
yerr = np.concatenate((dBerr20,dBerr21,dBerr22,dBerr23))
x = np.concatenate((x20*v20,x21*v21,x22*v22,x23*v23))

plt.xlabel(r'$\frac{4\pi}{c} \varrho v_{CO}$ [$10^{-15}$ cm$^{-3/2}$ g$^{1/2}$ s$^{-1}$]')
plt.ylabel(r'$\frac{\partial B_y}{\partial x}-\frac{\partial B_x}{\partial y}$ [$10^{-18}$ cm$^{-3/2}$ g$^{1/2}$ s$^{-1}$]')
plt.xlim(0.2, 2)

######
from scipy.optimize import curve_fit

def func(x, a, b):
    return a * x + b

popt, pcov = curve_fit(func, x, y, sigma=yerr, absolute_sigma=True, method='dogbox')
print(popt)
print(np.sqrt(np.diag(pcov)))
#####curve_fit not working when no x*1e15 and y*1e18, use polyfit

z3_fit, z3_cov = np.polyfit(x, y, 1, cov =True, w=1/yerr)
print(z3_fit)
print(np.sqrt(np.diag(z3_cov)))

import uncertainties.unumpy as unp
import uncertainties as unc

a2,b2 = unc.correlated_values(z3_fit, z3_cov)
print('Uncertainty')
print('a2: ' + str(a2))
print('b2: ' + str(b2))

xp = np.linspace(0.2, 2, 100)
py2 = a2*xp+b2
nom1 = unp.nominal_values(py2)
std1 = unp.std_devs(py2)

plt.fill_between(xp, nom1 - 1.96 * std1, nom1 + 1.96 * std1, facecolor='grey', interpolate=True,
                linewidth=0.0,alpha=0.2,label='95% Confidence Region',zorder=0)
plt.plot(xp, nom1, 'k-')

plt.savefig('dB_vz_outflow_final_2024_cgs2_chan_241022_paerrweight_Xe_positiveJ.pdf')

#[2.98293759e-04 2.49918524e-19]
#[5.58693730e-35 4.77096961e-20]
#[2.98293759e-04 2.49918524e-19]
#[1.66320203e-04 2.04026938e-19]
#Uncertainty
#a2: 0.00030+/-0.00017
#b2: (-2.5+/-2.0)e-19
# Out:
# <style>.container { width:100% !important; }</style>
# [ 0.29829377 -0.24991852]
# [0.13056906 0.16017058]
# [ 0.29829377 -0.24991852]
# [0.16632019 0.20402692]
# Uncertainty
# a2: 0.30+/-0.17
# b2: -0.25+/-0.20

# %%
print(3.0/1.7)
print(2.5/2.0)
